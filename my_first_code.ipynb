# %% [markdown]
# LSE Data Analytics Online Career Accelerator¶
# DA201: Data Analytics using Python

# %%
# This is my first line of code
print("My name is Maria Angelica Garcia")
print("The date is 1 July 2026")
# Out:
# My name is Maria Angelica Garcia
# The date is 1 July 2026

# %% [markdown]
# Analyse real estate data

# %%
# Write a program to analyse real estate data. 
# December sales
a=45000
b=23400
c=67000
d=34600
e=12900
sales_price=a, b, c, d, e
commission = 5000, 3400, 6500, 4000, 1500
Property_price = 40000, 20000, "none" , 30600, 11400

# %%
#Find the total sales for the month.
print(sales_price)
total_sales=sum(sales_price)
print(total_sales)
# Out:
# (45000, 23400, 67000, 34600, 12900)
# 182900

# %%
#Calculate the average sales price
average_sales = total_sales / len(sales_price)
print(average_sales)
# Out:
# 36580.0

# %%
#Find the missing value
# Sales price = Property price + Commission; Property price = Sales price - Commission
property_price_c = sales_price[2] - commission [2] 

print(property_price_c)
# Out:
# 60500
