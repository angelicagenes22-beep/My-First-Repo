# %%
#print statement

print("Hello World")
# Out:
# Hello World

# %%
print("Hello World")
# Out:
# Hello World

# %%
#if statement

if 5>2:
    print ("Hello World")
# Out:
# Hello World

# %%
2*5+6
# Out:
# 16

# %%
2*(5+6)
# Out:
# 22

# %%
#list

list1 = ['apple',5,'orange']

# %%
print(list1)
# Out:
# ['apple', 5, 'orange']

# %%
list1[2]
# Out:
# 'orange'

# %%
#create new variable
n=300
print(n)
# Out:
# 300

# %%
#Print a single variable
var_a=100
var_b=100.05
name="Soni"

# %%
print(name)
# Out:
# Soni

# %%
print(var_a)
print(var_b)
print(name)
# Out:
# 100
# 100.05
# Soni

# %%
a=50
b=50
c=50
print(a)
# Out:
# 50

# %%
print(a)
print(b)
print(c)
print(a,b,c)
# Out:
# 50
# 50
# 50
# 50 50 50

# %%
# Assign multiple values to multiple variables.
# Demonstrating the = operator.
a, b, c = 50, 50, 50

# %%
# Stipulate a single value to be assigned to multiple variables.
a, b, c = 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[87], line 2
#       1 # Stipulate a single value to be assigned to multiple variables.
# ----> 2 a, b, c = 50
#
# TypeError: cannot unpack non-iterable int object

# %%
aa, ba, ca =5, 50.25, "Python"

# %%
print(cc)
# Out:
# Python

# %%
print(aa,ba,ca)
# Out:
# 5 50.25 Python

# %%
property_id="C"

# %%
sales_amount=67000

# %%
commission=6500

# %%
property_price=(sales_amount-commission)

# %%
print(property_price)
# Out:
# 60500

# %%
# Demonstrating the + operator.
a +=5

# %%
print(a)
# Out:
# 65

# %%
# Demonstrating the addition operator.
ab=10
bb=5

# %%
print(ab+bb)
# Out:
# 15

# %%
# Demonstrating the subtraction operator.
print(ab-bb)
# Out:
# 5

# %%
print(ab%bb)
# Out:
# 0

# %%
# Demonstrating the exponent operator.
print(ab**2)
# Out:
# 100

# %%
# Demonstrating the 'or' operator.
ac = 10
bc = 0.2

if ac > 0 or bc > 0:
    print("Either number is greater than 0.")
    
else:
    print("No number is greater than 0.")
# Out:
# Either number is greater than 0.

# %%
# Demonstrating the 'not' operator.
x = 10

if not (x > 10):
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
# Demonstrating the 'in' operator.
xx = ['cat', 'dog']

print('cat' in xx)
# Out:
# True

# %%
# Demonstrating the 'not in' operator.
xx = ['cat', 'dog']

print('Monkey' not in xx)
# Out:
# True

# %%
#1.2.4 Practical activity: Writing your first line of code
